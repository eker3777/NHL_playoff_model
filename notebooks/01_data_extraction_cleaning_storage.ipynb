# %% [markdown]
# # 01 - Data Extraction, Cleaning, and Storage
# This notebook reuses the existing scraping logic to gather missing data for 2026 and stores outputs in `data/raw/`, `data/processed/`, and `data/final/`.

# %%
from pathlib import Path

ROOT = Path("..").resolve()
RAW_DIR = ROOT / "data" / "raw"
PROCESSED_DIR = ROOT / "data" / "processed"
FINAL_DIR = ROOT / "data" / "final"

RAW_DIR, PROCESSED_DIR, FINAL_DIR
