# %% [markdown]
# # 03 - Feature Engineering (Head-to-Head Advantages)
#
# Build advantage-style features such as offensive_rating - opponent_defensive_rating and other matchup deltas.

# %%
from pathlib import Path

ROOT = Path("..").resolve()
RAW_DIR = ROOT / "data" / "raw"
PROCESSED_DIR = ROOT / "data" / "processed"
FINAL_DIR = ROOT / "data" / "final"

RAW_DIR, PROCESSED_DIR, FINAL_DIR
