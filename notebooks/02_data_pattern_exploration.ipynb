# %% [markdown]
# # 02 - Initial Data Pattern Exploration
#
# Use this notebook to inspect which features are correlated with playoff wins before feature engineering.

# %%
from pathlib import Path

ROOT = Path("..").resolve()
RAW_DIR = ROOT / "data" / "raw"
PROCESSED_DIR = ROOT / "data" / "processed"
FINAL_DIR = ROOT / "data" / "final"

RAW_DIR, PROCESSED_DIR, FINAL_DIR
