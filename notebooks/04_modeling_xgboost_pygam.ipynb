# %% [markdown]
# # 04 - Modeling (XGBoost + pyGAM)
# Train two model families: (A) tuned XGBoost with ipex GPU support and CV stratified by year, and (B) pyGAM with separate metric groups (team performance, playoff history, context).

# %%
from pathlib import Path

ROOT = Path("..").resolve()
RAW_DIR = ROOT / "data" / "raw"
PROCESSED_DIR = ROOT / "data" / "processed"
FINAL_DIR = ROOT / "data" / "final"

RAW_DIR, PROCESSED_DIR, FINAL_DIR
